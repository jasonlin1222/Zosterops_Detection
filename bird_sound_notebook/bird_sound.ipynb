# %% [markdown]
# # Bird Sound Recognize

# %% [markdown]
# ## Value Setting

# %% [markdown]
# ### Mount at Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### Train Value

# %%
SOUND_PATH = r"/content/gdrive/MyDrive/Bird_sound/dataset/raw"
DATASET_PATH = r"/content/gdrive/MyDrive/Bird_sound/dataset/Tyler_data"
WAV_PATH = r""

MODEL_NAME = "Model_test"

TIME_STEP = 20 
SOUND_LENGTH = 128
TEST_DATA_RATIO = 0.2
INPUT_SHAPE = (TIME_STEP, SOUND_LENGTH)
CLASSES = ["before_net", "build_net","fail", "hug_egg", "out_net", "spawn", "yu_zhu_gi"]

MODEL_CONV1DS = [165, 165]
MODEL_LAYERS = [512, 256, 128, 64, 32]
BATCH_SIZE = 60
EPOCHS = 100

# %% [markdown]
# #### debug

# %%
# !pip uninstall h5py -y
# !pip install h5py==2.10 -i https://pypi.tuna.tsinghua.edu.cn/simple/
# Out:
# Found existing installation: h5py 2.10.0
# Uninstalling h5py-2.10.0:
#   Successfully uninstalled h5py-2.10.0
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting h5py==2.10
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/3f/c0/abde58b837e066bca19a3f7332d9d0493521d7dd6b48248451a9e3fe2214/h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from h5py==2.10) (1.21.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py==2.10) (1.15.0)
# Installing collected packages: h5py
# Successfully installed h5py-2.10.0

# %% [markdown]
# ## Prepare All Tool

# %% [markdown]
# ### Prepare Package

# %%
# %tensorflow_version 1.x
# !pip install keras-multi-head
import os
import random
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv1D, MaxPool1D, Flatten, Dropout
from tensorflow.keras.layers import Input, TimeDistributed, Dense, Embedding, LayerNormalization
from tensorflow.keras.utils import to_categorical
# from tensorflow.keras.layers import MultiHeadAttention
# from transformers import DistilBertTokenizerFast #, TFDistilBertModel
# from transformers import TFDistilBertForTokenClassification
from tqdm import tqdm_notebook as tqdm
import numpy as np
import matplotlib.pyplot as plt
import json
import librosa
import librosa.display
import pickle
from sklearn.metrics import classification_report
import itertools
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Sound Proccess Tool

# %%
class SoundProcessor:
    def __init__(self):
        self.data = []
        self.sr = None

    def load_sound(self, path):
        self.data, self.sr = librosa.load(path)
        return self.data

    def transform_mfcc(self, data):
        mfcc = librosa.feature.mfcc(y=data, sr=self.sr, n_mfcc=SOUND_LENGTH)
        arr = mfcc.T #分貝
        arr = arr[np.shape(arr)[0] % TIME_STEP:, :]
        return arr

    def plot_mfcc(self, data, save_path):
        arr = librosa.feature.mfcc(y=data, sr=self.sr, dct_type=3)
        arr = arr.T
        mfccArr = arr[np.shape(arr)[0] % TIME_STEP:, :]
        count = 0
        if mfccArr.shape[0] < TIME_STEP:
            print("Arr is too short, ignored.", mfccArr.shape)
            return
        for subArr in np.split(mfccArr, mfccArr.shape[0] // TIME_STEP):
            count += 1
            fig, ax = plt.subplots()
            img = librosa.display.specshow(subArr, ax=ax)
            fig.colorbar(img, ax=ax)
            fig.savefig(save_path[:-4] + f"_{count}.png")
            fig.clear()

    def bird_sound_all_classes_json(self, load_folder, save_path):
        if not os.path.exists(save_path):
            os.mkdir(save_path)
        for folder in os.listdir(load_folder):
            load_path = os.path.join(load_folder, folder)
            folderData = []
            for filename in os.listdir(os.path.join(load_path)):
                data = self.load_sound(os.path.join(load_path, filename))
                mfccArr = self.transform_mfcc(data)
                if mfccArr.shape[0] < TIME_STEP:
                    print(filename, "arr is too short, ignored.", mfccArr.shape)
                    continue
                for subArr in np.split(mfccArr, mfccArr.shape[0] // TIME_STEP):
                    # print("test")
                    # print(len(subArr[0]))
                    folderData.append(subArr.tolist())
                print(filename, " done.")
            split_idx = max(1, int(len(folderData) * TEST_DATA_RATIO))
            random.shuffle(folderData)
            test_arr = folderData[:split_idx]
            train_arr = folderData[split_idx:]
            # print(test_arr)
            # print(train_arr)
            filename = os.path.join(save_path, folder + ".json")
            with open(filename, "w") as f:
                print(np.array(test_arr).shape)
                print(np.array(train_arr).shape)
                data = {"test": test_arr, "train": train_arr}
                json.dump(data, f)
            print(folder + ".json", " saved.  \n", "Located: ", filename)

        print("Every folder have done!")
        print(f"Save at path: {save_path}")
        print("==================================================================================================")

    def bird_sound_all_classes_npy(self, load_folder, save_path):
        if not os.path.exists(save_path):
            os.mkdir(save_path)
        for folder in os.listdir(load_folder):
            load_path = os.path.join(load_folder, folder)
            folderData = []
            for filename in os.listdir(os.path.join(load_path)):
                data = self.load_sound(os.path.join(load_path, filename))
                mfccArr = self.transform_mfcc(data)
                if mfccArr.shape[0] < TIME_STEP:
                    print(filename, "arr is too short, ignored.", mfccArr.shape)
                    continue
                for subArr in np.split(mfccArr, mfccArr.shape[0] // TIME_STEP):
                    folderData.append(subArr)
                print(filename, " done.")
            split_idx = max(1, int(len(folderData) * TEST_DATA_RATIO))
            test_arr = folderData[:split_idx]
            train_arr = folderData[split_idx:]
            random.shuffle(folderData)
            test_npy_folder = os.path.join(save_path, "test")
            train_npy_folder = os.path.join(save_path, "train")
            if not os.path.exists(test_npy_folder):
                os.mkdir(test_npy_folder)
            if not os.path.exists(train_npy_folder):
                os.mkdir(train_npy_folder)
            test_npy_filename = os.path.join(test_npy_folder, folder + ".npy")
            train_npy_filename = os.path.join(train_npy_folder, folder + ".npy")
            np.save(test_npy_filename, np.asarray(test_arr))
            # print(test_arr)
            np.save(train_npy_filename, np.asarray(train_arr))
            print(test_npy_filename, "saved. length:", TIME_STEP, " x ", SOUND_LENGTH)
            print(train_npy_filename, "saved. length:", TIME_STEP, " x ", SOUND_LENGTH)

        print("Every folder have done!")
        print(f"Save at path: {save_path}")
        print("==================================================================================================")

    def instant_transform(self, data):
        mfccArr = self.transform_mfcc(data)
        if mfccArr.shape[0] < TIME_STEP:
            print("Video is too short, can't recognize.")
            return np.array([])
        queue = [subArr for subArr in np.split(mfccArr, mfccArr.shape[0] // TIME_STEP)]
        return np.array(queue)

    def load_json(self, load_folder):
        x_train = []
        y_train = []
        x_test = []
        y_test = []
        for y, filename in enumerate(os.listdir(os.path.join(load_folder, "JSON"))):
            load_path = os.path.join(load_folder, "JSON", filename)
            print(load_path)
            data = json.load(open(load_path))
            print(f"{filename} have loaded.")
            x_test += data["test"]
            x_train += data["train"]
            for i in range(len(data["test"])):
                y_test.append(y)
            for i in range(len(data["train"])):
                y_train.append(y)

        return np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test)

    def load_npy(self, load_folder):
        x_train = []
        y_train = []
        x_test = []
        y_test = []
        for y, filename in enumerate(os.listdir(os.path.join(load_folder, "NPY", "train"))):
            load_path = os.path.join(load_folder, "NPY", "train", filename)
            print(load_path)
            data = np.load(load_path, allow_pickle=True)
            print(f"{filename} have loaded, shape: ", data.shape)
            x_train += data.tolist()
            for i in range(data.shape[0]):
                y_train.append(y)

        for y, filename in enumerate(os.listdir(os.path.join(load_folder, "NPY", "test"))):
            load_path = os.path.join(load_folder, "NPY", "test", filename)
            print(load_path)
            data = np.load(load_path, allow_pickle=True)
            print(f"{filename} have loaded, shape: ", data.shape)
            x_test += data.tolist()
            for i in range(data.shape[0]):
                y_test.append(y)
        return np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test)


    def plot_bird_sound_all_classes(self, load_folder, save_path):
        if not os.path.exists(save_path):
            os.mkdir(save_path)
        for folder in os.listdir(load_folder):
            if not os.path.exists(os.path.join(save_path, folder)):
                os.mkdir(os.path.join(save_path, folder))
            load_path = os.path.join(load_folder, folder)
            for filename in os.listdir(os.path.join(load_path)):
                path = os.path.join(save_path, folder, filename)
                data = self.load_sound(os.path.join(load_path, filename))
                self.plot_mfcc(data, path)
                print(folder + ".json", " have plot.  \n", "Located: ", path)

        print("Every figure have done!")
        print(f"Save at path: {save_path}")
        print("==================================================================================================")

# %% [markdown]
# ### Model Create Tool

# %% [markdown]
# #### Classes TransForm

# %%
def classes_change(mode):
    for i, C in enumerate(CLASSES):
        if i == mode:
            return C
    return "None"

# %% [markdown]
# #### Model Basic Functions

# %%
def setting(model):
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def fit(model, x_train, y_train, x_test, y_test, batch, epochs):
    y_train = to_categorical(y_train, 7)
    y_test = to_categorical(y_test, 7)
    print("START TRAINING==================================================================")
    train_history = model.fit(x=x_train, y=y_train,
                  validation_split=0.2,
                  epochs=epochs,
                  batch_size=batch,
                  verbose=2,
                  validation_data=(x_test, y_test),
                  shuffle=True,
                  )
    return model, train_history

def save(model, save_path, name):
    if not os.path.exists(save_path):
        os.mkdir(save_path)
    model.save(os.path.join(save_path, name+".h5"))
    print("Model have saved.")

def load(save_path):
    model = keras.models.load_model(save_path+".h5")
    model.summary()
    return model

# %% [markdown]
# #### Create Model

# %% [markdown]
# ##### Conv1D Model

# %%
def createConv1DModel(
        name,
        n_conv1Ds,
        n_layers,
        d_input,
        n_classes):
    """
    @param name: model name
    @param n_conv1Ds: filters of conv1D
    @param n_layers: filters of dense
    @param d_input: input shape
    @param n_classes: output classes
    @return: model
    """

    model = Sequential(name=f"{name}")
    model.add(Conv1D(1024, kernel_size=3, input_shape=d_input, activation="relu"))
    model.add(MaxPool1D(pool_size=2))
    for i in n_conv1Ds[1:]:
        if i == 0:
            model.add(Dropout(0.2))
        else:
            model.add(Conv1D(i, kernel_size=3, activation="relu"))
            model.add(MaxPool1D(pool_size=2))
    model.add(Flatten())
    for i in n_layers:
        if i == 0:
            model.add(Dropout(0.2))
        else:
            model.add(Dense(i, activation="relu"))
    model.add(Dense(len(n_classes), activation="softmax"))
    model.summary()
    return model

# %% [markdown]
# #### Get model

# %%
def get_model():
    return createConv1DModel("model",
                  MODEL_CONV1DS,
                  MODEL_LAYERS,
                  INPUT_SHAPE,
                  CLASSES,
                  )

# %% [markdown]
# #### Predict Function

# %%
def predict_classes(model, data):
    prediction = [np.argmax(arr) for arr in model.predict(data)]
    predict_class = [classes_change(arr) for arr in prediction]
    return prediction, predict_class

# %% [markdown]
# #### Test Function

# %%
def test(model, x_test, y_test, test_time=10):
    success = 0
    predictions, classes = predict_classes(model, x_test)
    for i in range(test_time):
        index = random.randint(0, len(x_test))
        predict = predictions[index]
        print(f"test{i+1}\t| prediction: ", classes[index], "\n     \t| answer: ", classes_change(y_test[index]))
        if predict == y_test[index]:
            print(f"Match\t| [ O ]")
            success += 1
        else:
            print(f"Match\t| [ X ]")
    print("Accuracy: ", success/test_time, "%.")

# %% [markdown]
# #### Plot Model's Accuracy & Loss

# %%
def load_history(load_path, name):
    with open(os.path.join(load_path, name+"_history.p"), 'rb') as f:
        history = pickle.load(f)
    print("History have loaded")
    return history


def save_history(history, save_path, name):
  history = history.history
  if not os.path.exists(save_path):
    os.mkdir(save_path)
  with open(os.path.join(save_path, name+"_history.p"), 'wb') as f:
      pickle.dump(history, f)
  print("History have saved")


def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name, is_save=True, save_path=""):
    '''
    This function will plot the metrics passed to it in a graph.
    Args:
        model_training_history: A history object containing a record of training and validation
                                loss values and metrics values at successive epochs
        metric_name_1:          The name of the first metric that needs to be plotted in the graph.
        metric_name_2:          The name of the second metric that needs to be plotted in the graph.
        plot_name:              The title of the graph.
    '''

    # Get metric values using metric names as identifiers.
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]

    # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
    epochs = range(len(metric_value_1))
    # Plot the Graph.
    fig = plt.figure()
    plt.plot(epochs, metric_value_1, 'blue', label=metric_name_1)
    plt.plot(epochs, metric_value_2, 'red', label=metric_name_2)

    # Add title to the plot.
    plt.title(str(plot_name))

    # Add legend to the plot.
    plt.legend()
    plt.show()
    if not os.path.exists(save_path) and is_save:
      os.mkdir(save_path)

    if is_save and save_path != "":
      fig.savefig(save_path+".png")

def plot_all(model_training_history):
  plot_metric(model_training_history, "loss", "val_loss", "Train Loss Vs Train Val Loss",
        True, os.path.join(DATASET_PATH, "MODEL", MODEL_NAME + "_loss"))
  plot_metric(model_training_history, "acc", "val_acc", "Train Acc Vs Train Val Acc",
        True, os.path.join(DATASET_PATH, "MODEL", MODEL_NAME + "_acc"))

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
def plot(history, save_path, name):
    if not os.path.exists(save_path):
        os.mkdir(save_path)
    print(history.history.keys())
    fig = plt.figure()
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    fig.savefig(os.path.join(save_path, f"{name}_accuracy.png"))

    fig = plt.figure()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    fig.savefig(os.path.join(save_path, f"{name}_loss.png"))

# %% [markdown]
# ### Main wav proccess

# %%
def main_wav_process(mode):
    soundTool = SoundProcessor()
    if mode == "npy":
        soundTool.bird_sound_all_classes_npy(SOUND_PATH, os.path.join(DATASET_PATH, "NPY"))
    elif mode == "json":
        soundTool.bird_sound_all_classes_json(SOUND_PATH, os.path.join(DATASET_PATH, "JSON"))

# %% [markdown]
# ### Data Loader

# %%
def data_loader(mode):
    soundTool = SoundProcessor()
    if mode == "npy":
        x_train, y_train, x_test, y_test = soundTool.load_npy(DATASET_PATH)
    elif mode == "json":
        x_train, y_train, x_test, y_test = soundTool.load_json(DATASET_PATH)
    else:
        print("Please choice data type.")
        return
    return x_train, y_train, x_test, y_test

# %% [markdown]
# ### Main Training

# %%
def main_training(x_train, y_train, x_test, y_test, modelname):
    print("x_train: ", x_train.shape)
    print("y_train: ", y_train.shape)
    print("x_test: ", x_test.shape)
    print("y_test: ", y_test.shape)
    model = get_model()
    model = setting(model)
    model, history = fit(model,
                x_train, y_train,
                x_test, y_test,
                BATCH_SIZE,
                EPOCHS,
                )
    save(model, os.path.join(DATASET_PATH, "MODEL"), modelname)
    return model, history

# %% [markdown]
# ### Main Plot

# %%
def main_plot(history):
    plot_all(history)

# %%
def main_confusion(x_test, y_test):
  y_predict = model.predict(x_test)
  y_pred = y_predict.argmax(axis=-1)
  one_hot_y_test = to_categorical(y_test)
  y_true = one_hot_y_test.argmax(axis=-1)
  target_names = CLASSES
  fig = plt.figure(figsize=(15, 15), dpi=100)
  cnf_martrix = confusion_matrix(y_true, y_pred)

  plot_confusion_matrix(cnf_martrix, classes=target_names, normalize=True,
                      title="bird sound recognize confusion matrix")
  plt.show()

  fig.savefig(f'{DATASET_PATH}/FIGURE/confusion_matrix_{MODEL_NAME}.png')

# %% [markdown]
# ### Main Testing

# %%
def main_testing(x_test, y_test):
    model = load(os.path.join(DATASET_PATH, "MODEL", MODEL_NAME))
    test(model, x_test, y_test, 150)

# %% [markdown]
# ### Main Test wav

# %%
def main_test_wav(wav_path):
    model = load(os.path.join(DATASET_PATH, "MODEL", MODEL_NAME))
    soundTool = SoundProcessor()
    data = soundTool.load_sound(wav_path)
    mfccData = soundTool.instant_transform(data)
    if mfccData.shape[0] != np.array([]).shape[0]:
        predictions, classes = predict_classes(model, mfccData)
        print("Prediction: ", max(classes))

# %% [markdown]
# ### Main Get MFCC figure

# %%
def main_mfcc_figure():
  soundTool = SoundProcessor()
  soundTool.plot_bird_sound_all_classes(SOUND_PATH, os.path.join(DATASET_PATH, "FIGURE"))

# %% [markdown]
# ## RUN PLACE

# %%
# main_wav_process("npy")
# main_wav_process("json")

# %%
x_train, y_train, x_test, y_test = data_loader("json")
# Out:
# /content/gdrive/MyDrive/Bird_sound/dataset/Tyler_data/JSON/yu_zhu_qi.json
# yu_zhu_qi.json have loaded.
# /content/gdrive/MyDrive/Bird_sound/dataset/Tyler_data/JSON/spawn.json
# spawn.json have loaded.
# /content/gdrive/MyDrive/Bird_sound/dataset/Tyler_data/JSON/fail.json
# fail.json have loaded.
# /content/gdrive/MyDrive/Bird_sound/dataset/Tyler_data/JSON/before_net.json
# before_net.json have loaded.
# /content/gdrive/MyDrive/Bird_sound/dataset/Tyler_data/JSON/hug_egg.json
# hug_egg.json have loaded.
# /content/gdrive/MyDrive/Bird_sound/dataset/Tyler_data/JSON/out_nest.json
# out_nest.json have loaded.
# /content/gdrive/MyDrive/Bird_sound/dataset/Tyler_data/JSON/build_nest.json
# build_nest.json have loaded.

# %%
model, history = main_training(x_train, y_train, x_test, y_test, MODEL_NAME)
# Out:
# x_train:  (8101, 20, 128)
# y_train:  (8101,)
# x_test:  (2021, 20, 128)
# y_test:  (2021,)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_35 (Conv1D)           (None, 18, 1024)          394240
# _________________________________________________________________
# max_pooling1d_32 (MaxPooling (None, 9, 1024)           0
# _________________________________________________________________
# conv1d_36 (Conv1D)           (None, 7, 165)            507045
# _________________________________________________________________
# max_pooling1d_33 (MaxPooling (None, 3, 165)            0
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 495)               0
# _________________________________________________________________
# dense_96 (Dense)             (None, 512)               253952
# _________________________________________________________________
# dense_97 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_98 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_99 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_100 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_101 (Dense)            (None, 7)                 231
# =================================================================
# Total params: 1,330,028
# Trainable params: 1,330,028
# Non-trainable params: 0
# _________________________________________________________________
# START TRAINING==================================================================
# Train on 8101 samples, validate on 2021 samples
# Epoch 1/100
# 8101/8101 - 4s - loss: 1.8963 - acc: 0.4703 - val_loss: 1.1757 - val_acc: 0.6304
# Epoch 2/100
# 8101/8101 - 2s - loss: 0.5857 - acc: 0.7866 - val_loss: 0.4378 - val_acc: 0.8476
# Epoch 3/100
# 8101/8101 - 2s - loss: 0.3748 - acc: 0.8658 - val_loss: 1.0568 - val_acc: 0.7155
# Epoch 4/100
# 8101/8101 - 2s - loss: 0.4157 - acc: 0.8583 - val_loss: 0.2657 - val_acc: 0.9159
# Epoch 5/100
# 8101/8101 - 2s - loss: 0.2123 - acc: 0.9295 - val_loss: 0.2145 - val_acc: 0.9258
# Epoch 6/100
# 8101/8101 - 2s - loss: 0.1363 - acc: 0.9554 - val_loss: 0.2476 - val_acc: 0.9203
# Epoch 7/100
# 8101/8101 - 2s - loss: 0.1345 - acc: 0.9558 - val_loss: 0.2242 - val_acc: 0.9342
# Epoch 8/100
# 8101/8101 - 1s - loss: 0.1139 - acc: 0.9622 - val_loss: 0.2440 - val_acc: 0.9193
# Epoch 9/100
# 8101/8101 - 1s - loss: 0.1127 - acc: 0.9619 - val_loss: 0.2215 - val_acc: 0.9401
# Epoch 10/100
# 8101/8101 - 1s - loss: 0.0763 - acc: 0.9743 - val_loss: 0.2617 - val_acc: 0.9273
# Epoch 11/100
# 8101/8101 - 1s - loss: 0.0734 - acc: 0.9758 - val_loss: 0.2789 - val_acc: 0.9302
# Epoch 12/100
# 8101/8101 - 1s - loss: 0.0586 - acc: 0.9823 - val_loss: 0.2858 - val_acc: 0.9233
# Epoch 13/100
# 8101/8101 - 1s - loss: 0.0652 - acc: 0.9807 - val_loss: 0.2823 - val_acc: 0.9149
# Epoch 14/100
# 8101/8101 - 1s - loss: 0.0749 - acc: 0.9764 - val_loss: 0.2908 - val_acc: 0.9307
# Epoch 15/100
# 8101/8101 - 1s - loss: 0.0478 - acc: 0.9841 - val_loss: 0.3398 - val_acc: 0.9119
# Epoch 16/100
# 8101/8101 - 1s - loss: 0.0734 - acc: 0.9793 - val_loss: 0.4758 - val_acc: 0.8906
# Epoch 17/100
# 8101/8101 - 1s - loss: 0.0518 - acc: 0.9833 - val_loss: 0.2064 - val_acc: 0.9520
# Epoch 18/100
# 8101/8101 - 1s - loss: 0.0259 - acc: 0.9925 - val_loss: 0.3337 - val_acc: 0.9297
# Epoch 19/100
# 8101/8101 - 1s - loss: 0.0426 - acc: 0.9877 - val_loss: 0.2464 - val_acc: 0.9446
# Epoch 20/100
# 8101/8101 - 1s - loss: 0.0408 - acc: 0.9880 - val_loss: 0.2713 - val_acc: 0.9466
# Epoch 21/100
# 8101/8101 - 1s - loss: 0.0260 - acc: 0.9931 - val_loss: 0.2274 - val_acc: 0.9500
# Epoch 22/100
# 8101/8101 - 1s - loss: 0.0519 - acc: 0.9841 - val_loss: 0.2560 - val_acc: 0.9396
# Epoch 23/100
# 8101/8101 - 1s - loss: 0.0312 - acc: 0.9909 - val_loss: 0.2380 - val_acc: 0.9471
# Epoch 24/100
# 8101/8101 - 1s - loss: 0.0163 - acc: 0.9953 - val_loss: 0.2703 - val_acc: 0.9367
# Epoch 25/100
# 8101/8101 - 1s - loss: 0.0339 - acc: 0.9900 - val_loss: 0.2930 - val_acc: 0.9381
# Epoch 26/100
# 8101/8101 - 1s - loss: 0.0719 - acc: 0.9807 - val_loss: 0.2700 - val_acc: 0.9377
# Epoch 27/100
# 8101/8101 - 1s - loss: 0.0490 - acc: 0.9863 - val_loss: 0.3133 - val_acc: 0.9421
# Epoch 28/100
# 8101/8101 - 1s - loss: 0.0413 - acc: 0.9883 - val_loss: 0.2857 - val_acc: 0.9466
# Epoch 29/100
# 8101/8101 - 1s - loss: 0.0341 - acc: 0.9909 - val_loss: 0.3162 - val_acc: 0.9327
# Epoch 30/100
# 8101/8101 - 1s - loss: 0.0558 - acc: 0.9861 - val_loss: 0.2478 - val_acc: 0.9446
# Epoch 31/100
# 8101/8101 - 1s - loss: 0.0249 - acc: 0.9933 - val_loss: 0.2603 - val_acc: 0.9426
# Epoch 32/100
# 8101/8101 - 1s - loss: 0.0211 - acc: 0.9946 - val_loss: 0.2530 - val_acc: 0.9446
# Epoch 33/100
# 8101/8101 - 1s - loss: 0.0077 - acc: 0.9978 - val_loss: 0.2810 - val_acc: 0.9525
# Epoch 34/100
# 8101/8101 - 1s - loss: 0.0203 - acc: 0.9941 - val_loss: 0.2552 - val_acc: 0.9436
# Epoch 35/100
# 8101/8101 - 1s - loss: 0.0522 - acc: 0.9881 - val_loss: 0.4121 - val_acc: 0.9223
# Epoch 36/100
# 8101/8101 - 1s - loss: 0.0408 - acc: 0.9895 - val_loss: 0.2823 - val_acc: 0.9471
# Epoch 37/100
# 8101/8101 - 1s - loss: 0.0228 - acc: 0.9938 - val_loss: 0.2736 - val_acc: 0.9357
# Epoch 38/100
# 8101/8101 - 1s - loss: 0.0323 - acc: 0.9912 - val_loss: 0.2298 - val_acc: 0.9570
# Epoch 39/100
# 8101/8101 - 1s - loss: 0.0109 - acc: 0.9974 - val_loss: 0.2823 - val_acc: 0.9490
# Epoch 40/100
# 8101/8101 - 1s - loss: 0.0138 - acc: 0.9970 - val_loss: 0.3179 - val_acc: 0.9466
# Epoch 41/100
# 8101/8101 - 1s - loss: 0.0214 - acc: 0.9948 - val_loss: 0.2893 - val_acc: 0.9550
# Epoch 42/100
# 8101/8101 - 1s - loss: 0.0312 - acc: 0.9919 - val_loss: 0.3528 - val_acc: 0.9426
# Epoch 43/100
# 8101/8101 - 1s - loss: 0.0503 - acc: 0.9889 - val_loss: 0.2758 - val_acc: 0.9332
# Epoch 44/100
# 8101/8101 - 1s - loss: 0.0343 - acc: 0.9905 - val_loss: 0.3024 - val_acc: 0.9401
# Epoch 45/100
# 8101/8101 - 1s - loss: 0.0162 - acc: 0.9957 - val_loss: 0.3032 - val_acc: 0.9401
# Epoch 46/100
# 8101/8101 - 1s - loss: 0.0213 - acc: 0.9951 - val_loss: 0.2942 - val_acc: 0.9401
# Epoch 47/100
# 8101/8101 - 1s - loss: 0.0221 - acc: 0.9941 - val_loss: 0.3106 - val_acc: 0.9386
# Epoch 48/100
# 8101/8101 - 1s - loss: 0.0153 - acc: 0.9958 - val_loss: 0.2763 - val_acc: 0.9510
# Epoch 49/100
# 8101/8101 - 1s - loss: 0.0262 - acc: 0.9933 - val_loss: 0.2666 - val_acc: 0.9490
# Epoch 50/100
# 8101/8101 - 1s - loss: 0.0111 - acc: 0.9968 - val_loss: 0.3128 - val_acc: 0.9476
# Epoch 51/100
# 8101/8101 - 1s - loss: 0.0153 - acc: 0.9962 - val_loss: 0.2902 - val_acc: 0.9500
# Epoch 52/100
# 8101/8101 - 1s - loss: 0.0117 - acc: 0.9970 - val_loss: 0.2962 - val_acc: 0.9525
# Epoch 53/100
# 8101/8101 - 1s - loss: 0.0227 - acc: 0.9948 - val_loss: 0.3257 - val_acc: 0.9401
# Epoch 54/100
# 8101/8101 - 1s - loss: 0.0134 - acc: 0.9962 - val_loss: 0.3057 - val_acc: 0.9515
# Epoch 55/100
# 8101/8101 - 1s - loss: 0.0085 - acc: 0.9984 - val_loss: 0.4489 - val_acc: 0.9297
# Epoch 56/100
# 8101/8101 - 1s - loss: 0.0351 - acc: 0.9919 - val_loss: 0.2774 - val_acc: 0.9495
# Epoch 57/100
# 8101/8101 - 1s - loss: 0.0385 - acc: 0.9909 - val_loss: 0.3029 - val_acc: 0.9372
# Epoch 58/100
# 8101/8101 - 1s - loss: 0.0336 - acc: 0.9914 - val_loss: 0.2700 - val_acc: 0.9555
# Epoch 59/100
# 8101/8101 - 1s - loss: 0.0082 - acc: 0.9983 - val_loss: 0.3848 - val_acc: 0.9322
# Epoch 60/100
# 8101/8101 - 1s - loss: 0.0178 - acc: 0.9954 - val_loss: 0.2394 - val_acc: 0.9480
# Epoch 61/100
# 8101/8101 - 1s - loss: 0.0193 - acc: 0.9964 - val_loss: 0.2798 - val_acc: 0.9456
# Epoch 62/100
# 8101/8101 - 1s - loss: 0.0416 - acc: 0.9917 - val_loss: 0.2533 - val_acc: 0.9510
# Epoch 63/100
# 8101/8101 - 1s - loss: 0.0483 - acc: 0.9879 - val_loss: 0.3320 - val_acc: 0.9421
# Epoch 64/100
# 8101/8101 - 1s - loss: 0.0332 - acc: 0.9909 - val_loss: 0.3030 - val_acc: 0.9500
# Epoch 65/100
# 8101/8101 - 1s - loss: 0.0178 - acc: 0.9964 - val_loss: 0.2952 - val_acc: 0.9515
# Epoch 66/100
# 8101/8101 - 1s - loss: 0.0022 - acc: 0.9994 - val_loss: 0.3709 - val_acc: 0.9525
# Epoch 67/100
# 8101/8101 - 1s - loss: 2.7842e-04 - acc: 0.9999 - val_loss: 0.4026 - val_acc: 0.9505
# Epoch 68/100
# 8101/8101 - 1s - loss: 0.0416 - acc: 0.9930 - val_loss: 0.3800 - val_acc: 0.9327
# Epoch 69/100
# 8101/8101 - 1s - loss: 0.0378 - acc: 0.9902 - val_loss: 0.5885 - val_acc: 0.9352
# Epoch 70/100
# 8101/8101 - 1s - loss: 0.0306 - acc: 0.9935 - val_loss: 0.3850 - val_acc: 0.9352
# Epoch 71/100
# 8101/8101 - 1s - loss: 0.0052 - acc: 0.9986 - val_loss: 0.3078 - val_acc: 0.9540
# Epoch 72/100
# 8101/8101 - 1s - loss: 5.1597e-04 - acc: 0.9999 - val_loss: 0.3256 - val_acc: 0.9545
# Epoch 73/100
# 8101/8101 - 1s - loss: 0.0096 - acc: 0.9979 - val_loss: 0.3981 - val_acc: 0.9416
# Epoch 74/100
# 8101/8101 - 1s - loss: 0.0192 - acc: 0.9954 - val_loss: 0.3432 - val_acc: 0.9466
# Epoch 75/100
# 8101/8101 - 1s - loss: 0.0274 - acc: 0.9938 - val_loss: 0.3384 - val_acc: 0.9510
# Epoch 76/100
# 8101/8101 - 1s - loss: 0.0444 - acc: 0.9893 - val_loss: 0.3239 - val_acc: 0.9421
# Epoch 77/100
# 8101/8101 - 1s - loss: 0.0497 - acc: 0.9894 - val_loss: 0.3025 - val_acc: 0.9431
# Epoch 78/100
# 8101/8101 - 1s - loss: 0.0846 - acc: 0.9858 - val_loss: 0.3569 - val_acc: 0.9332
# Epoch 79/100
# 8101/8101 - 1s - loss: 0.0357 - acc: 0.9923 - val_loss: 0.2885 - val_acc: 0.9594
# Epoch 80/100
# 8101/8101 - 1s - loss: 0.0029 - acc: 0.9998 - val_loss: 0.3495 - val_acc: 0.9550
# Epoch 81/100
# 8101/8101 - 1s - loss: 0.0123 - acc: 0.9972 - val_loss: 0.3408 - val_acc: 0.9396
# Epoch 82/100
# 8101/8101 - 1s - loss: 0.0585 - acc: 0.9853 - val_loss: 0.3067 - val_acc: 0.9574
# Epoch 83/100
# 8101/8101 - 1s - loss: 0.0131 - acc: 0.9977 - val_loss: 0.3340 - val_acc: 0.9476
# Epoch 84/100
# 8101/8101 - 1s - loss: 0.0031 - acc: 0.9991 - val_loss: 0.3700 - val_acc: 0.9579
# Epoch 85/100
# 8101/8101 - 1s - loss: 0.0088 - acc: 0.9979 - val_loss: 0.2973 - val_acc: 0.9515
# Epoch 86/100
# 8101/8101 - 1s - loss: 5.5872e-04 - acc: 1.0000 - val_loss: 0.3018 - val_acc: 0.9589
# Epoch 87/100
# 8101/8101 - 1s - loss: 9.1802e-05 - acc: 1.0000 - val_loss: 0.3258 - val_acc: 0.9574
# Epoch 88/100
# 8101/8101 - 1s - loss: 2.5305e-05 - acc: 1.0000 - val_loss: 0.3360 - val_acc: 0.9579
# Epoch 89/100
# 8101/8101 - 1s - loss: 1.6992e-05 - acc: 1.0000 - val_loss: 0.3456 - val_acc: 0.9589
# Epoch 90/100
# 8101/8101 - 1s - loss: 6.8083e-04 - acc: 0.9999 - val_loss: 0.5120 - val_acc: 0.9579
# Epoch 91/100
# 8101/8101 - 1s - loss: 0.0506 - acc: 0.9886 - val_loss: 0.3602 - val_acc: 0.9159
# Epoch 92/100
# 8101/8101 - 1s - loss: 0.0308 - acc: 0.9940 - val_loss: 0.2820 - val_acc: 0.9396
# Epoch 93/100
# 8101/8101 - 1s - loss: 0.0242 - acc: 0.9949 - val_loss: 0.4202 - val_acc: 0.9322
# Epoch 94/100
# 8101/8101 - 1s - loss: 0.0184 - acc: 0.9969 - val_loss: 0.3248 - val_acc: 0.9505
# Epoch 95/100
# 8101/8101 - 1s - loss: 0.0023 - acc: 0.9996 - val_loss: 0.3478 - val_acc: 0.9535
# Epoch 96/100
# 8101/8101 - 1s - loss: 2.6102e-04 - acc: 1.0000 - val_loss: 0.3471 - val_acc: 0.9570
# Epoch 97/100
# 8101/8101 - 1s - loss: 2.4889e-05 - acc: 1.0000 - val_loss: 0.3551 - val_acc: 0.9570
# Epoch 98/100
# 8101/8101 - 1s - loss: 1.5446e-05 - acc: 1.0000 - val_loss: 0.3621 - val_acc: 0.9570
# Epoch 99/100
# 8101/8101 - 1s - loss: 1.1406e-05 - acc: 1.0000 - val_loss: 0.3683 - val_acc: 0.9570
# Epoch 100/100
# 8101/8101 - 1s - loss: 8.9189e-06 - acc: 1.0000 - val_loss: 0.3743 - val_acc: 0.9570
# Model have saved.

# %%
save_history(history, os.path.join(DATASET_PATH, "HISTORY"), MODEL_NAME)
# Out:
# History have saved

# %%
main_plot(history)

# %%
main_testing(x_test, y_test)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_35 (Conv1D)           (None, 18, 1024)          394240
# _________________________________________________________________
# max_pooling1d_32 (MaxPooling (None, 9, 1024)           0
# _________________________________________________________________
# conv1d_36 (Conv1D)           (None, 7, 165)            507045
# _________________________________________________________________
# max_pooling1d_33 (MaxPooling (None, 3, 165)            0
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 495)               0
# _________________________________________________________________
# dense_96 (Dense)             (None, 512)               253952
# _________________________________________________________________
# dense_97 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_98 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_99 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_100 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_101 (Dense)            (None, 7)                 231
# =================================================================
# Total params: 1,330,028
# Trainable params: 1,330,028
# Non-trainable params: 0
# _________________________________________________________________
# test1	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test2	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test3	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test4	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test5	| prediction:  fail
#      	| answer:  fail
# Match	| [ O ]
# test6	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test7	| prediction:  before_net
#      	| answer:  before_net
# Match	| [ O ]
# test8	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test9	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test10	| prediction:  hug_egg
#      	| answer:  hug_egg
# Match	| [ O ]
# test11	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test12	| prediction:  fail
#      	| answer:  fail
# Match	| [ O ]
# test13	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test14	| prediction:  hug_egg
#      	| answer:  hug_egg
# Match	| [ O ]
# test15	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test16	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test17	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test18	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test19	| prediction:  fail
#      	| answer:  fail
# Match	| [ O ]
# test20	| prediction:  hug_egg
#      	| answer:  hug_egg
# Match	| [ O ]
# test21	| prediction:  fail
#      	| answer:  fail
# Match	| [ O ]
# test22	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test23	| prediction:  before_net
#      	| answer:  before_net
# Match	| [ O ]
# test24	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test25	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test26	| prediction:  fail
#      	| answer:  fail
# Match	| [ O ]
# test27	| prediction:  hug_egg
#      	| answer:  hug_egg
# Match	| [ O ]
# test28	| prediction:  before_net
#      	| answer:  before_net
# Match	| [ O ]
# test29	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test30	| prediction:  fail
#      	| answer:  out_net
# Match	| [ X ]
# test31	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test32	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test33	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test34	| prediction:  out_net
#      	| answer:  yu_zhu_gi
# Match	| [ X ]
# test35	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test36	| prediction:  fail
#      	| answer:  fail
# Match	| [ O ]
# test37	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test38	| prediction:  before_net
#      	| answer:  before_net
# Match	| [ O ]
# test39	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test40	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test41	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test42	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test43	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test44	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test45	| prediction:  hug_egg
#      	| answer:  hug_egg
# Match	| [ O ]
# test46	| prediction:  fail
#      	| answer:  fail
# Match	| [ O ]
# test47	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test48	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test49	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test50	| prediction:  yu_zhu_gi
#      	| answer:  fail
# Match	| [ X ]
# test51	| prediction:  hug_egg
#      	| answer:  hug_egg
# Match	| [ O ]
# test52	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test53	| prediction:  build_net
#      	| answer:  hug_egg
# Match	| [ X ]
# test54	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test55	| prediction:  before_net
#      	| answer:  before_net
# Match	| [ O ]
# test56	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test57	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test58	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test59	| prediction:  fail
#      	| answer:  fail
# Match	| [ O ]
# test60	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test61	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test62	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test63	| prediction:  fail
#      	| answer:  out_net
# Match	| [ X ]
# test64	| prediction:  fail
#      	| answer:  fail
# Match	| [ O ]
# test65	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test66	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test67	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test68	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test69	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test70	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test71	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test72	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test73	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test74	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test75	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test76	| prediction:  fail
#      	| answer:  fail
# Match	| [ O ]
# test77	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test78	| prediction:  hug_egg
#      	| answer:  hug_egg
# Match	| [ O ]
# test79	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test80	| prediction:  hug_egg
#      	| answer:  hug_egg
# Match	| [ O ]
# test81	| prediction:  hug_egg
#      	| answer:  hug_egg
# Match	| [ O ]
# test82	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test83	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test84	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test85	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test86	| prediction:  before_net
#      	| answer:  before_net
# Match	| [ O ]
# test87	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test88	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test89	| prediction:  fail
#      	| answer:  fail
# Match	| [ O ]
# test90	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test91	| prediction:  fail
#      	| answer:  out_net
# Match	| [ X ]
# test92	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test93	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test94	| prediction:  before_net
#      	| answer:  before_net
# Match	| [ O ]
# test95	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test96	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test97	| prediction:  hug_egg
#      	| answer:  hug_egg
# Match	| [ O ]
# test98	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test99	| prediction:  fail
#      	| answer:  fail
# Match	| [ O ]
# test100	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test101	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test102	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test103	| prediction:  hug_egg
#      	| answer:  hug_egg
# Match	| [ O ]
# test104	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test105	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test106	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test107	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test108	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test109	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test110	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test111	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test112	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test113	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test114	| prediction:  hug_egg
#      	| answer:  hug_egg
# Match	| [ O ]
# test115	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test116	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test117	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test118	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test119	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test120	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test121	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test122	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test123	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test124	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test125	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test126	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test127	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test128	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test129	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test130	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test131	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test132	| prediction:  hug_egg
#      	| answer:  hug_egg
# Match	| [ O ]
# test133	| prediction:  hug_egg
#      	| answer:  hug_egg
# Match	| [ O ]
# test134	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test135	| prediction:  out_net
#      	| answer:  out_net
# Match	| [ O ]
# test136	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test137	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test138	| prediction:  fail
#      	| answer:  fail
# Match	| [ O ]
# test139	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test140	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test141	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test142	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test143	| prediction:  yu_zhu_gi
#      	| answer:  yu_zhu_gi
# Match	| [ O ]
# test144	| prediction:  hug_egg
#      	| answer:  hug_egg
# Match	| [ O ]
# test145	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test146	| prediction:  build_net
#      	| answer:  build_net
# Match	| [ O ]
# test147	| prediction:  out_net
#      	| answer:  yu_zhu_gi
# Match	| [ X ]
# test148	| prediction:  build_net
#      	| answer:  before_net
# Match	| [ X ]
# test149	| prediction:  spawn
#      	| answer:  spawn
# Match	| [ O ]
# test150	| prediction:  hug_egg
#      	| answer:  hug_egg
# Match	| [ O ]
# Accuracy:  0.9466666666666667 %.

# %%
main_confusion(x_test, y_test)
# Out:
# Normalized confusion matrix
# [[0.96153846 0.01282051 0.         0.01923077 0.         0.00641026
#   0.        ]
#  [0.         0.98461538 0.00769231 0.         0.00384615 0.
#   0.00384615]
#  [0.00485437 0.00485437 0.91262136 0.02427184 0.01941748 0.01941748
#   0.01456311]
#  [0.         0.00772201 0.01158301 0.93436293 0.01158301 0.
#   0.03474903]
#  [0.         0.00234192 0.02576112 0.00234192 0.95316159 0.00234192
#   0.01405152]
#  [0.         0.         0.00771208 0.         0.         0.98457584
#   0.00771208]
#  [0.         0.         0.0154321  0.00925926 0.02160494 0.00308642
#   0.95061728]]
